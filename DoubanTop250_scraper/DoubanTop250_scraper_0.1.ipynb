# %%
import requests
from bs4 import BeautifulSoup
import pprint
import json
import pandas as pd


#构造分页数字列表
page_indexs = range(0, 250, 25)
list(page_indexs)

def download_all_htmls():
    """
    下载所有列表页面的HTML，用于后续分析
    """
    #user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 Edg/116.0.1938.62
    #将user-agent添加到HTTP请求头中
    
    #headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36'}
    htmls = []
    headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
          'cookie':'bid=_zhfF-ZbaBo; _gid=GA1.2.1119014521.1693273295; ll="108288"; _ga_Y4GN1R87RG=GS1.1.1693273294.1.1.1693273343.0.0.0; Hm_lvt_19fc7b106453f97b6a84d64302f21a04=1693273344; Hm_lpvt_19fc7b106453f97b6a84d64302f21a04=1693273344; _ga=GA1.2.618442902.1693273294; _ga_PRH9EWN86K=GS1.2.1693273346.1.0.1693273346.0.0.0; _pk_id.100001.4cf6=f7764ed1b187faa5.1693273366.; ap_v=0,6.0; __utmc=30149280; __utmc=223695111; __yadk_uid=yJHosNbGXoyAIzzidv0xmF3nCvUSTGBx; _pk_ref.100001.4cf6=%5B%22%22%2C%22%22%2C1693277239%2C%22https%3A%2F%2Fwww.baidu.com%2Flink%3Furl%3DxVyHf7QVWrDzwzEOtf2E5Rw5pNkDBwoJYapsobZd8Yk8vPxuSUan-PP-s6t9JXTE%26wd%3D%26eqid%3D8724702400076e420000000364ed4d11%22%5D; _pk_ses.100001.4cf6=1; dbcl2="155720260:BSgj1oGmpnk"; ck=OimW; __utma=30149280.618442902.1693273294.1693273366.1693277276.2; __utmb=30149280.0.10.1693277276; __utmz=30149280.1693277276.2.2.utmcsr=accounts.douban.com|utmccn=(referral)|utmcmd=referral|utmcct=/; __utma=223695111.618442902.1693273294.1693273366.1693277276.2; __utmb=223695111.0.10.1693277276; __utmz=223695111.1693277276.2.2.utmcsr=accounts.douban.com|utmccn=(referral)|utmcmd=referral|utmcct=/; push_noty_num=0; push_doumail_num=0'}
    for idx in page_indexs:
        url = f"https://movie.douban.com/top250?start={idx}&filter="
        headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
          'cookie':'bid=_zhfF-ZbaBo; _gid=GA1.2.1119014521.1693273295; ll="108288"; _ga_Y4GN1R87RG=GS1.1.1693273294.1.1.1693273343.0.0.0; Hm_lvt_19fc7b106453f97b6a84d64302f21a04=1693273344; Hm_lpvt_19fc7b106453f97b6a84d64302f21a04=1693273344; _ga=GA1.2.618442902.1693273294; _ga_PRH9EWN86K=GS1.2.1693273346.1.0.1693273346.0.0.0; _pk_id.100001.4cf6=f7764ed1b187faa5.1693273366.; ap_v=0,6.0; __utmc=30149280; __utmc=223695111; __yadk_uid=yJHosNbGXoyAIzzidv0xmF3nCvUSTGBx; _pk_ref.100001.4cf6=%5B%22%22%2C%22%22%2C1693277239%2C%22https%3A%2F%2Fwww.baidu.com%2Flink%3Furl%3DxVyHf7QVWrDzwzEOtf2E5Rw5pNkDBwoJYapsobZd8Yk8vPxuSUan-PP-s6t9JXTE%26wd%3D%26eqid%3D8724702400076e420000000364ed4d11%22%5D; _pk_ses.100001.4cf6=1; dbcl2="155720260:BSgj1oGmpnk"; ck=OimW; __utma=30149280.618442902.1693273294.1693273366.1693277276.2; __utmb=30149280.0.10.1693277276; __utmz=30149280.1693277276.2.2.utmcsr=accounts.douban.com|utmccn=(referral)|utmcmd=referral|utmcct=/; __utma=223695111.618442902.1693273294.1693273366.1693277276.2; __utmb=223695111.0.10.1693277276; __utmz=223695111.1693277276.2.2.utmcsr=accounts.douban.com|utmccn=(referral)|utmcmd=referral|utmcct=/; push_noty_num=0; push_doumail_num=0'}
        print("craw html:", url)
        r = requests.get(url, headers=headers)
        if r.status_code != 200:
            raise Exception("error")
        htmls.append(r.text)
    return htmls

# %%
#执行爬取
htmls = download_all_htmls()
print(htmls[1])
# Out:
# craw html: https://movie.douban.com/top250?start=0&filter=
# craw html: https://movie.douban.com/top250?start=25&filter=
# craw html: https://movie.douban.com/top250?start=50&filter=
# craw html: https://movie.douban.com/top250?start=75&filter=
# craw html: https://movie.douban.com/top250?start=100&filter=
# craw html: https://movie.douban.com/top250?start=125&filter=
# craw html: https://movie.douban.com/top250?start=150&filter=
# craw html: https://movie.douban.com/top250?start=175&filter=
# craw html: https://movie.douban.com/top250?start=200&filter=
# craw html: https://movie.douban.com/top250?start=225&filter=
# <!DOCTYPE html>
# <html lang="zh-CN" class="ua-windows ">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
# 豆瓣电影 Top 250
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2006 01:00:00 GMT">
#
#     <link rel="apple-touch-icon" href="https://img1.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">
#     <link href="https://img1.doubanio.com/f/vendors/02814fbb5bee25484516bd0a642af695f7ec5a83/css/douban.css" rel="stylesheet" type="text/css">
#     <link href="https://img1.doubanio.com/f/vendors/ee6598d46af0bc554cecec9bcbf525b9b0582cb0/css/separation/_all.css" rel="stylesheet" type="text/css">
#     <link href="https://img1.doubanio.com/f/movie/cb1cb6aaa244dff6a281d103ff26d445debd130a/dist/movie/base/init.css" rel="stylesheet">
#     <script type="text/javascript">var _head_start = new Date();</script>
#     <script type="text/javascript" src="https://img1.doubanio.com/f/vendors/0511abe9863c2ea7084efa7e24d1d86c5b3974f1/js/jquery-1.10.2.min.js"></script>
#     <script type="text/javascript" src="https://img1.doubanio.com/f/vendors/aa9559674f2476cdc16f755b3cdc4ebc478db669/js/douban.js"></script>
#     <script type="text/javascript" src="https://img1.doubanio.com/f/vendors/b0d3faaf7a432605add54908e39e17746824d6cc/js/separation/_all.js"></script>
#
# <link href="https://img1.doubanio.com/f/movie/cc39edebfb5def77e34478f63618b37c894e5499/dist/movie/charts/top_movies.css" rel="stylesheet" type="text/css" />
#
#     <style type="text/css">
# .site-nav-logo img{margin-bottom:0;}
# </style>
#     <style type="text/css">img { max-width: 100%; }</style>
#     <script type="text/javascript"></script>
#     <style type="text/css">
#     .item .playable {font-size: 13px; padding-left: 3px; color: #00A65F;}
#     .tabs {
#       overflow: hidden;
#       float: left;
#     }
#     .tabs a,
#     .tabs span {
#       display: block;
#       float: left;
#       height: 25px;
#       line-height: 25px;
#       padding: 0 15px;
#       -webkit-border-radius: 3px;
#       border-radius: 3px;
#       font-size: 13px;
#     }
#
#     .tabs a:hover {
#       background: none;
#       color: #37a;
#     }
#
#     .tabs span {
#       background: #268dcd;
#       color: #fff;
#     }
#
#     .opt {
#       margin-top: 15px;
#       padding-bottom: 0;
#     }
#     .mod #mine-selector {
#       display: block;
#       margin-top: 6px;
#       float:right;
#       color: #666666;
#       font-size: 12px;
#     }
# </style>
#
#     <link rel="shortcut icon" href="https://img1.doubanio.com/favicon.ico" type="image/x-icon">
# </head>
#
# <body>
#
#     <script type="text/javascript">var _body_start = new Date();</script>
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/164cfd8/shire/bundle.css" rel="stylesheet" type="text/css">
#
#
#
# <div id="db-global-nav" class="global-nav">
#   <div class="bd">
#
# <div class="top-nav-info">
#   <ul>
#     <li>
#     <a id="top-nav-doumail-link" href="https://www.douban.com/doumail/">豆邮</a>
#     </li>
#     <li class="nav-user-account">
#       <a target="_blank" href="https://accounts.douban.com/passport/setting/" class="bn-more">
#         <span>Vodka的账号</span><span class="arrow"></span>
#       </a>
#       <div class="more-items">
#         <table cellpadding="0" cellspacing="0">
#           <tbody>
#             <tr>
#               <td>
#                 <a href="https://www.douban.com/mine/">个人主页</a>
#               </td>
#             </tr>
#             <tr>
#               <td>
#                 <a target="_blank" href="https://www.douban.com/mine/orders/">我的订单</a>
#               </td>
#             </tr>
#             <tr>
#               <td>
#                 <a target="_blank" href="https://www.douban.com/mine/wallet/">我的钱包</a>
#               </td>
#             </tr>
#             <tr>
#               <td>
#                 <a target="_blank" href="https://accounts.douban.com/passport/setting/">账号管理</a>
#               </td>
#             </tr>
#             <tr>
#               <td>
#                 <a href="https://www.douban.com/accounts/logout?source=movie&ck=OimW">退出</a>
#               </td>
#             </tr>
#           </tbody>
#         </table>
#       </div>
#     </li>
#   </ul>
# </div>
#
#   <div class="top-nav-reminder">
#     <a href="https://www.douban.com/notification/" class="lnk-remind">提醒</a>
#     <div id="top-nav-notimenu" class="more-items">
#       <div class="bd">
#         <p>加载中...</p>
#       </div>
#     </div>
#   </div>
#
#     <div class="top-nav-doubanapp">
#   <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>
#   <div id="doubanapp-tip">
#     <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 <span class="version">6.0</span> 全新发布</a>
#     <a href="javascript: void 0;" class="tip-close">×</a>
#   </div>
#   <div id="top-nav-appintro" class="more-items">
#     <p class="appintro-title">豆瓣</p>
#     <p class="qrcode">扫码直接下载</p>
#     <div class="download">
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>
#       <span>·</span>
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>
#     </div>
#   </div>
# </div>
#
#
#
#
# <div class="global-nav-items">
#   <ul>
#     <li class="">
#       <a href="https://www.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-main&quot;,&quot;uid&quot;:&quot;155720260&quot;}">豆瓣</a>
#     </li>
#     <li class="">
#       <a href="https://book.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-book&quot;,&quot;uid&quot;:&quot;155720260&quot;}">读书</a>
#     </li>
#     <li class="on">
#       <a href="https://movie.douban.com"  data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-movie&quot;,&quot;uid&quot;:&quot;155720260&quot;}">电影</a>
#     </li>
#     <li class="">
#       <a href="https://music.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-music&quot;,&quot;uid&quot;:&quot;155720260&quot;}">音乐</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/location" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-location&quot;,&quot;uid&quot;:&quot;155720260&quot;}">同城</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/group" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-group&quot;,&quot;uid&quot;:&quot;155720260&quot;}">小组</a>
#     </li>
#     <li class="">
#       <a href="https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-read&quot;,&quot;uid&quot;:&quot;155720260&quot;}">阅读</a>
#     </li>
#     <li class="">
#       <a href="https://fm.douban.com&#47;?from_=shire_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-fm&quot;,&quot;uid&quot;:&quot;155720260&quot;}">FM</a>
#     </li>
#     <li class="">
#       <a href="https://time.douban.com&#47;?dt_time_source=douban-web_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-time&quot;,&quot;uid&quot;:&quot;155720260&quot;}">时间</a>
#     </li>
#     <li class="">
#       <a href="https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-market&quot;,&quot;uid&quot;:&quot;155720260&quot;}">豆品</a>
#     </li>
#   </ul>
# </div>
#
#   </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     USER_ID: "155720260",
#     UPLOAD_AUTH_TOKEN: "155720260:87b68ec51b242a2ad537a57006ef5ffc22fdeb6f",
#     SSE_TOKEN: "0d94c602413d11cb86b0cb3d9847de7565dc25f4",
#     SSE_TIMESTAMP: "1693316424",
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/164cfd8/shire/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/164cfd8/movie/bundle.css" rel="stylesheet" type="text/css">
#
#
#
#
# <div id="db-nav-movie" class="nav">
#   <div class="nav-wrap">
#   <div class="nav-primary">
#     <div class="nav-logo">
#       <a href="https:&#47;&#47;movie.douban.com">豆瓣电影</a>
#     </div>
#     <div class="nav-search">
#       <form action="https:&#47;&#47;search.douban.com&#47;movie/subject_search" method="get">
#         <fieldset>
#           <legend>搜索：</legend>
#           <label for="inp-query">
#           </label>
#           <div class="inp"><input id="inp-query" name="search_text" size="22" maxlength="60" placeholder="搜索电影、电视剧、综艺、影人" value=""></div>
#           <div class="inp-btn"><input type="submit" value="搜索"></div>
#           <input type="hidden" name="cat" value="1002" />
#         </fieldset>
#       </form>
#     </div>
#   </div>
#   </div>
#   <div class="nav-secondary">
#
#
# <div class="nav-items">
#   <ul>
#     <li    ><a href="https://movie.douban.com/mine"
#      >我看</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/cinema/nowplaying/"
#      >影讯&购票</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/explore"
#      >选电影</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/tv/"
#      >电视剧</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/chart"
#      >排行榜</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/review/best/"
#      >影评</a>
#     </li>
#     <li    ><a href="https://movie.douban.com/annual/2022?fullscreen=1&source=navigation"
#      >2022年度榜单</a>
#     </li>
#     <li    ><a href="https://standbyme2022.douban.com/?autorotate=false&fullscreen=true&hidenav=true&source=web_navigation"
#             target="_blank"
#      >2022书影音报告</a>
#     </li>
#   </ul>
# </div>
#
#     <a href="https://movie.douban.com/annual/2022?fullscreen=1&source=movie_navigation" class="movieannual"></a>
#   </div>
# </div>
#
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
#
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/164cfd8/movie/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#     <div id="wrapper">
#
#
#
#     <div id="content">
#
#     <h1>豆瓣电影 Top 250</h1>
#
#         <div class="grid-16-8 clearfix">
#
#
#             <div class="article">
#
#
#
#
#
#
#
#
# <div class="opt mod">
#     <div class="tabs">
#
#
#
#     </div>
#     <span id="mine-selector">
#       <input type="checkbox"  value="unwatched">我没看过的(182)
#     </span>
# </div>
#
#
#
# <ol class="grid_view">
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">26</em>
#                     <a href="https://movie.douban.com/subject/1291560/">
#                         <img width="100" alt="龙猫" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2540924496.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1291560/" class="">
#                             <span class="title">龙猫</span>
#                                     <span class="title">&nbsp;/&nbsp;となりのトトロ</span>
#                                 <span class="other">&nbsp;/&nbsp;邻居托托罗  /  邻家的豆豆龙</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 宫崎骏 Hayao Miyazaki&nbsp;&nbsp;&nbsp;主演: 日高法子 Noriko Hidaka / 坂本千夏 Ch...<br>
#                             1988&nbsp;/&nbsp;日本&nbsp;/&nbsp;动画 奇幻 冒险
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.2</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>1272802人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">人人心中都有个龙猫，童年就永远不会消失。</span>
#                             </p>
#
#
#     <p>
#
#         <span class="gact">
#             <a href="https://movie.douban.com/wish/155720260/update?add=1291560" target="_blank" class="j a_collect_btn" name="sbtn-1291560-wish" rel="nofollow">想看</a>
#         </span>&nbsp;&nbsp;
#             </p>
#
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">27</em>
#                     <a href="https://movie.douban.com/subject/20495023/">
#                         <img width="100" alt="寻梦环游记" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2896589968.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/20495023/" class="">
#                             <span class="title">寻梦环游记</span>
#                                     <span class="title">&nbsp;/&nbsp;Coco</span>
#                                 <span class="other">&nbsp;/&nbsp;玩转极乐园(港)  /  可可夜总会(台)</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 李·昂克里奇 Lee Unkrich / 阿德里安·莫利纳 Adrian Molina&nbsp;&nbsp;&nbsp;主演: ...<br>
#                             2017&nbsp;/&nbsp;美国&nbsp;/&nbsp;喜剧 动画 奇幻 音乐
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.1</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>
p>
#
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">49</em>
#                     <a href="https://movie.douban.com/subject/1291572/">
#                         <img width="100" alt="指环王2：双塔奇兵" src="https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2640236255.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1291572/" class="">
#                             <span class="title">指环王2：双塔奇兵</span>
#                                     <span class="title">&nbsp;/&nbsp;The Lord of the Rings: The Two Towers</span>
#                                 <span class="other">&nbsp;/&nbsp;魔戒二部曲：双城奇谋  /  指环王II：双塔</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 彼得·杰克逊 Peter Jackson&nbsp;&nbsp;&nbsp;主演: 伊利亚·伍德 Elijah Wood / 西恩...<br>
#                             2002&nbsp;/&nbsp;美国 新西兰&nbsp;/&nbsp;剧情 动作 奇幻 冒险
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.2</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>756826人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">承前启后的史诗篇章。</span>
#                             </p>
#
#
#     <p>
#
#         <span class="gact">
#             <a href="https://movie.douban.com/collection/155720260/update?add=1291572" target="_blank" class="j a_collect_btn" name="sbtn-1291572-collection" rel="nofollow">看过</a>
#         </span>&nbsp;&nbsp;
#     </p>
#
#                     </div>
#                 </div>
#             </div>
#         </li>
#         <li>
#             <div class="item">
#                 <div class="pic">
#                     <em class="">50</em>
#                     <a href="https://movie.douban.com/subject/1298624/">
#                         <img width="100" alt="闻香识女人" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2550757929.jpg" class="">
#                     </a>
#                 </div>
#                 <div class="info">
#                     <div class="hd">
#                         <a href="https://movie.douban.com/subject/1298624/" class="">
#                             <span class="title">闻香识女人</span>
#                                     <span class="title">&nbsp;/&nbsp;Scent of a Woman</span>
#                                 <span class="other">&nbsp;/&nbsp;女人香  /  女人的芳香</span>
#                         </a>
#
#
#                             <span class="playable">[可播放]</span>
#                     </div>
#                     <div class="bd">
#                         <p class="">
#                             导演: 马丁·布莱斯 Martin Brest&nbsp;&nbsp;&nbsp;主演: 阿尔·帕西诺 Al Pacino / 克里斯...<br>
#                             1992&nbsp;/&nbsp;美国&nbsp;/&nbsp;剧情
#                         </p>
#
#
#                         <div class="star">
#                                 <span class="rating45-t"></span>
#                                 <span class="rating_num" property="v:average">9.1</span>
#                                 <span property="v:best" content="10.0"></span>
#                                 <span>889171人评价</span>
#                         </div>
#
#                             <p class="quote">
#                                 <span class="inq">史上最美的探戈。</span>
#                             </p>
#
#
#     <p>
#
#         <span class="gact">
#             <a href="https://movie.douban.com/collection/155720260/update?add=1298624" target="_blank" class="j a_collect_btn" name="sbtn-1298624-collection" rel="nofollow">看过</a>
#         </span>&nbsp;&nbsp;
#     </p>
#
#                     </div>
#                 </div>
#             </div>
#         </li>
# </ol>
#
#
#
#
#
#
#
#         <div class="paginator">
#         <span class="prev">
#             <link rel="prev" href="?start=0&amp;filter="/>
#             <a href="?start=0&amp;filter=" >&lt;前页</a>
#         </span>
#
#
#
#
#             <a href="?start=0&amp;filter=" >1</a>
#
#                 <span class="thispage">2</span>
#
#             <a href="?start=50&amp;filter=" >3</a>
#
#
#             <a href="?start=75&amp;filter=" >4</a>
#
#
#             <a href="?start=100&amp;filter=" >5</a>
#
#
#             <a href="?start=125&amp;filter=" >6</a>
#
#
#             <a href="?start=150&amp;filter=" >7</a>
#
#
#             <a href="?start=175&amp;filter=" >8</a>
#
#
#             <a href="?start=200&amp;filter=" >9</a>
#
#
#             <a href="?start=225&amp;filter=" >10</a>
#
#         <span class="next">
#             <link rel="next" href="?start=50&amp;filter="/>
#             <a href="?start=50&amp;filter=" >后页&gt;</a>
#         </span>
#
#             <span class="count">(共250条)</span>
#         </div>
#
#
#
#             </div>
#             <div class="aside">
#
# <p class="pl">
#     豆瓣用户每天都在对“看过”的电影进行“很差”到“力荐”的评价，豆瓣根据每部影片看过的人数以及该影片所得的评价等综合数据，通过算法分析产生豆瓣电影 Top 250。
# </p>
#
# <div id="dale_movie_top250_bottom_right"></div>
#
# <!-- douban ad begin -->
#
#
#
#
# <link rel="stylesheet" href="https://img1.doubanio.com/f/movie/400d7765546ceac9b07913937f6a29d532d41690/dist/movie/ad/mobile_app_ad.css">
# <div class="mobile-app-entrance block5 app-movie">
#     <a class="entrance-link" href="https://www.douban.com/doubanapp/frodo">
#         <div class="entrance-qrcode">
#             <img src="https://img1.doubanio.com/f/movie/a02f6ed325fc52e220f299d51e730c422e2bcd16/pics/movie/douban_app_ad/qrcode.png" alt="扫码下载豆瓣 App" width="80" height="80" />
#         </div>
#         <div class="entrance-info">
#             <span class="app-icon icon-movie"></span>
#             <span class="main-title">豆瓣</span>
#             <span class="sub-title">让好电影来找你</span>
#         </div>
#     </a>
# </div>
#
# <!-- douban ad end -->
#
#
#             </div>
#             <div class="extra">
#
#             </div>
#         </div>
#     </div>
#
#
#     <div id="footer">
#             <div class="footer-extra"></div>
#
# <span id="icp" class="fleft gray-link">
#     &copy; 2005－2023 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
#
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
#
# <span class="fright">
#     <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about/legal">法律声明</a>
#
#     · <a href="https://help.douban.com/?app=movie" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
#
#     </div>
#
#     </div>
#     <!-- COLLECTED JS -->
#
#
#
#
#
#
#
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '155720260',
#             browserId = '_zhfF-ZbaBo',
#             criteria = '3:/top250?start=25&amp;filter=',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_top250_bottom_right'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', '//img1.doubanio.com/aHA2NWFxYy9mL2FkanMvYzMxYzA2OTAyN2E3NDg1NjI5OTE0Yzc0YTIzZDM2MGIyMzA1MmE4Yi9hZC5yZWxlYXNlLmpz?company_token=kX69T8w1wyOE-dale');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
#
#
#
#
#
#
#
#
#
#
#     <script type='text/javascript'>
#         $(function(){
#             $("#mine-selector input[type='checkbox']").click(function(){
#                 var val = $(this).is(":checked")?$(this).val():"";
#                 window.location.href = '/top250?filter=' + val;
#             })
#         })
#     </script>
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
#
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-19', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id]);
#       _gaq.push([method('_setSampleRate'), '5']);
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '1', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
#
#
#
#
#
#
#
#
#
#
#     <!-- dae-web-movie--default-67957896f4-rmg99-->
#
#   <script>_SPLITTEST=''</script>
# </body>
#
# </html>

# %%
#htmls[3]
# Out:
# '<!DOCTYPE html>\n<html lang="zh-CN" class="ua-windows ">\n<head>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n    <meta name="renderer" content="webkit">\n    <meta name="referrer" content="always">\n    <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />\n    <title>\n豆瓣电影 Top 250\n</title>\n    \n    <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="Expires" content="Sun, 6 Mar 2006 01:00:00 GMT">\n    \n    <link rel="apple-touch-icon" href="https://img1.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png">\n    <link href="https://img1.doubanio.com/f/vendors/02814fbb5bee25484516bd0a642af695f7ec5a83/css/douban.css" rel="stylesheet" type="text/css">\n    <link href="https://img1.doubanio.com/f/vendors/ee6598d46af0bc554cecec9bcbf525b9b0582cb0/css/separation/_all.css" rel="stylesheet" type="text/css">\n    <link href="https://img1.doubanio.com/f/movie/cb1cb6aaa244dff6a281d103ff26d445debd130a/dist/movie/base/init.css" rel="stylesheet">\n    <script type="text/javascript">var _head_start = new Date();</script>\n    <script type="text/javascript" src="https://img1.doubanio.com/f/vendors/0511abe9863c2ea7084efa7e24d1d86c5b3974f1/js/jquery-1.10.2.min.js"></script>\n    <script type="text/javascript" src="https://img1.doubanio.com/f/vendors/aa9559674f2476cdc16f755b3cdc4ebc478db669/js/douban.js"></script>\n    <script type="text/javascript" src="https://img1.doubanio.com/f/vendors/b0d3faaf7a432605add54908e39e17746824d6cc/js/separation/_all.js"></script>\n    \n<link href="https://img1.doubanio.com/f/movie/cc39edebfb5def77e34478f63618b37c894e5499/dist/movie/charts/top_movies.css" rel="stylesheet" type="text/css" />\n\n    <style type="text/css">\n.site-nav-logo img{margin-bottom:0;}\n</style>\n    <style type="text/css">img { max-width: 100%; }</style>\n    <script type="text/javascript"></script>\n    <style type="text/css">\n    .item .playable {font-size: 13px; padding-left: 3px; color: #00A65F;}\n    .tabs {\n      overflow: hidden;\n      float: left;\n    }\n    .tabs a,\n    .tabs span {\n      display: block;\n      float: left;\n      height: 25px;\n      line-height: 25px;\n      padding: 0 15px;\n      -webkit-border-radius: 3px;\n      border-radius: 3px;\n      font-size: 13px;\n    }\n\n    .tabs a:hover {\n      background: none;\n      color: #37a;\n    }\n\n    .tabs span {\n      background: #268dcd;\n      color: #fff;\n    }\n\n    .opt {\n      margin-top: 15px;\n      padding-bottom: 0;\n    }\n    .mod #mine-selector {\n      display: block;\n      margin-top: 6px;\n      float:right;\n      color: #666666;\n      font-size: 12px;\n    }\n</style>\n\n    <link rel="shortcut icon" href="https://img1.doubanio.com/favicon.ico" type="image/x-icon">\n</head>\n\n<body>\n  \n    <script type="text/javascript">var _body_start = new Date();</script>\n\n    \n    \n\n\n\n    <link href="//img3.doubanio.com/dae/accounts/resources/164cfd8/shire/bundle.css" rel="stylesheet" type="text/css">\n\n\n\n<div id="db-global-nav" class="global-nav">\n  <div class="bd">\n    \n<div class="top-nav-info">\n  <ul>\n    <li>\n    <a id="top-nav-doumail-link" href="https://www.douban.com/doumail/">豆邮</a>\n    </li>\n    <li class="nav-user-account">\n      <a target="_blank" href="https://accounts.douban.com/passport/setting/" class="bn-more">\n        <span>Vodka的账号</span><span class="arrow"></span>\n      </a>\n      <div class="more-items">\n        <table cellpadding="0" cellspacing="0">\n          <tbody>\n            <tr>\n              <td>\n                <a href="https://www.douban.com/mine/">个人主页</a>\n              </td>\n            </tr>\n            <tr>\n              <td>\n                <a target="_blank" href="https://www.douban.com/mine/orders/">我的订单</a>\n              </td>\n            </tr>\n            <tr>\n       ...

# %%
# 解析HTML得到数据

def parse_single_html(html):
    """
    解析单个HTML，得到数据
    @return list({"link", "title", [lable]})
    """
    soup = BeautifulSoup(html, 'html.parser')
    article_items = (soup.find("div", class_="article")
                         .find("ol", class_="grid_view")
                         .find_all("div", class_="item")
    )
    datas = []
    for article_item in article_items:
        rank = article_item.find("div", class_="pic").find("em").get_text()
        info = article_item.find("div", class_="info")
        title = info.find("div", class_="hd").find("span", class_="title").get_text()
        stars = (
            info.find("div", class_="bd")
                .find("div", class_="star")
                .find_all("span")
        )
        rating_star = stars[0]["class"][0]
        rating_num = stars[1].get_text()
        comments = stars[3].get_text()
        
        datas.append({
            "rank":rank,
            "title":title,
            "rating_star":rating_star.replace("rating","").replace("-t",""),
            "rating_num":rating_num,
            "comments":comments.replace("人评价","")
        })
    return datas

# %%
#pprint.pprint(parse_single_html(htmls[0]))
# Out:
# [{'comments': '2912712',
#   'rank': '1',
#   'rating_num': '9.7',
#   'rating_star': '5',
#   'title': '肖申克的救赎'},
#  {'comments': '2150318',
#   'rank': '2',
#   'rating_num': '9.6',
#   'rating_star': '5',
#   'title': '霸王别姬'},
#  {'comments': '2171440',
#   'rank': '3',
#   'rating_num': '9.5',
#   'rating_star': '5',
#   'title': '阿甘正传'},
#  {'comments': '2202843',
#   'rank': '4',
#   'rating_num': '9.5',
#   'rating_star': '5',
#   'title': '泰坦尼克号'},
#  {'comments': '2305154',
#   'rank': '5',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '这个杀手不太冷'},
#  {'comments': '2255304',
#   'rank': '6',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '千与千寻'},
#  {'comments': '1332350',
#   'rank': '7',
#   'rating_num': '9.6',
#   'rating_star': '5',
#   'title': '美丽人生'},
#  {'comments': '1110836',
#   'rank': '8',
#   'rating_num': '9.6',
#   'rating_star': '5',
#   'title': '辛德勒的名单'},
#  {'comments': '1849145',
#   'rank': '9',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '星际穿越'},
#  {'comments': '2071158',
#   'rank': '10',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '盗梦空间'},
#  {'comments': '1720687',
#   'rank': '11',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '楚门的世界'},
#  {'comments': '1404677',
#   'rank': '12',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '忠犬八公的故事'},
#  {'comments': '1685111',
#   'rank': '13',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '海上钢琴师'},
#  {'comments': '1866910',
#   'rank': '14',
#   'rating_num': '9.2',
#   'rating_star': '45',
#   'title': '三傻大闹宝莱坞'},
#  {'comments': '1317676',
#   'rank': '15',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '放牛班的春天'},
#  {'comments': '1322018',
#   'rank': '16',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '机器人总动员'},
#  {'comments': '1948715',
#   'rank': '17',
#   'rating_num': '9.2',
#   'rating_star': '45',
#   'title': '疯狂动物城'},
#  {'comments': '1370912',
#   'rank': '18',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '无间道'},
#  {'comments': '565096',
#   'rank': '19',
#   'rating_num': '9.6',
#   'rating_star': '5',
#   'title': '控方证人'},
#  {'comments': '1540708',
#   'rank': '20',
#   'rating_num': '9.2',
#   'rating_star': '45',
#   'title': '大话西游之大圣娶亲'},
#  {'comments': '935108',
#   'rank': '21',
#   'rating_num': '9.4',
#   'rating_star': '45',
#   'title': '熔炉'},
#  {'comments': '972641',
#   'rank': '22',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '教父'},
#  {'comments': '1119686',
#   'rank': '23',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '触不可及'},
#  {'comments': '1526743',
#   'rank': '24',
#   'rating_num': '9.2',
#   'rating_star': '45',
#   'title': '当幸福来敲门'},
#  {'comments': '890173',
#   'rank': '25',
#   'rating_num': '9.3',
#   'rating_star': '45',
#   'title': '末代皇帝'}]

# %%
# 执行所有HTML页面的解析

all_datas = []
for html in htmls:
    all_datas.extend(parse_single_html(html))

# %%
# all_datas
# Out:
# [{'rank': '1',
#   'title': '肖申克的救赎',
#   'rating_star': '5',
#   'rating_num': '9.7',
#   'comments': '2912712'},
#  {'rank': '2',
#   'title': '霸王别姬',
#   'rating_star': '5',
#   'rating_num': '9.6',
#   'comments': '2150318'},
#  {'rank': '3',
#   'title': '阿甘正传',
#   'rating_star': '5',
#   'rating_num': '9.5',
#   'comments': '2171440'},
#  {'rank': '4',
#   'title': '泰坦尼克号',
#   'rating_star': '5',
#   'rating_num': '9.5',
#   'comments': '2202843'},
#  {'rank': '5',
#   'title': '这个杀手不太冷',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '2305154'},
#  {'rank': '6',
#   'title': '千与千寻',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '2255304'},
#  {'rank': '7',
#   'title': '美丽人生',
#   'rating_star': '5',
#   'rating_num': '9.6',
#   'comments': '1332350'},
#  {'rank': '8',
#   'title': '辛德勒的名单',
#   'rating_star': '5',
#   'rating_num': '9.6',
#   'comments': '1110836'},
#  {'rank': '9',
#   'title': '星际穿越',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '1849145'},
#  {'rank': '10',
#   'title': '盗梦空间',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '2071158'},
#  {'rank': '11',
#   'title': '楚门的世界',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '1720687'},
#  {'rank': '12',
#   'title': '忠犬八公的故事',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '1404677'},
#  {'rank': '13',
#   'title': '海上钢琴师',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '1685111'},
#  {'rank': '14',
#   'title': '三傻大闹宝莱坞',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1866910'},
#  {'rank': '15',
#   'title': '放牛班的春天',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '1317676'},
#  {'rank': '16',
#   'title': '机器人总动员',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '1322018'},
#  {'rank': '17',
#   'title': '疯狂动物城',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1948715'},
#  {'rank': '18',
#   'title': '无间道',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '1370912'},
#  {'rank': '19',
#   'title': '控方证人',
#   'rating_star': '5',
#   'rating_num': '9.6',
#   'comments': '565096'},
#  {'rank': '20',
#   'title': '大话西游之大圣娶亲',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1540708'},
#  {'rank': '21',
#   'title': '熔炉',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '935108'},
#  {'rank': '22',
#   'title': '教父',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '972641'},
#  {'rank': '23',
#   'title': '触不可及',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '1119686'},
#  {'rank': '24',
#   'title': '当幸福来敲门',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1526743'},
#  {'rank': '25',
#   'title': '末代皇帝',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '890173'},
#  {'rank': '26',
#   'title': '龙猫',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1272802'},
#  {'rank': '27',
#   'title': '寻梦环游记',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1691327'},
#  {'rank': '28',
#   'title': '怦然心动',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1841480'},
#  {'rank': '29',
#   'title': '活着',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '848933'},
#  {'rank': '30',
#   'title': '蝙蝠侠：黑暗骑士',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1062718'},
#  {'rank': '31',
#   'title': '哈利·波特与魔法石',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '1198851'},
#  {'rank': '32',
#   'title': '指环王3：王者无敌',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '807066'},
#  {'rank': '33',
#   'title': '我不是药神',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '2115707'},
#  {'rank': '34',
#   'title': '乱世佳人',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '694858'},
#  {'rank': '35',
#   'title': '飞屋环游记',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1331827'},
#  {'rank': '36',
#   'title': '素媛',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '689904'},
#  {'rank': '37',
#   'title': '哈尔的移动城堡',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1031294'},
#  {'rank': '38',
#   'title': '十二怒汉',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '493298'},
#  {'rank': '39',
#   'title': '何以为家',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1049317'},
#  {'rank': '40',
#   'title': '摔跤吧！爸爸',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '1576529'},
#  {'rank': '41',
#   'title': '让子弹飞',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '1706980'},
#  {'rank': '42',
#   'title': '天空之城',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '878729'},
#  {'rank': '43',
#   'title': '鬼子来了',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '629536'},
#  {'rank': '44',
#   'title': '猫鼠游戏',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1030755'},
#  {'rank': '45',
#   'title': '少年派的奇幻漂流',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '1353919'},
#  {'rank': '46',
#   'title': '海蒂和爷爷',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '618534'},
#  {'rank': '47',
#   'title': '钢琴家',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '643397'},
#  {'rank': '48',
#   'title': '大话西游之月光宝盒',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '1226672'},
#  {'rank': '49',
#   'title': '指环王2：双塔奇兵',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '756826'},
#  {'rank': '50',
#   'title': '闻香识女人',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '889171'},
#  {'rank': '51',
#   'title': '罗马假日',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '954220'},
#  {'rank': '52',
#   'title': '死亡诗社',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '730304'},
#  {'rank': '53',
#   'title': '绿皮书',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '1657415'},
#  {'rank': '54',
#   'title': '天堂电影院',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '681032'},
#  {'rank': '55',
#   'title': '大闹天宫',
#   'rating_star': '45',
#   'rating_num': '9.4',
#   'comments': '440484'},
#  {'rank': '56',
#   'title': '指环王1：护戒使者',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '851017'},
#  {'rank': '57',
#   'title': '黑客帝国',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '841247'},
#  {'rank': '58',
#   'title': '教父2',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '555577'},
#  {'rank': '59',
#   'title': '狮子王',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '846115'},
#  {'rank': '60',
#   'title': '辩护人',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '590721'},
#  {'rank': '61',
#   'title': '饮食男女',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '623613'},
#  {'rank': '62',
#   'title': '搏击俱乐部',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '849426'},
#  {'rank': '63',
#   'title': '美丽心灵',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '771595'},
#  {'rank': '64',
#   'title': '本杰明·巴顿奇事',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '986354'},
#  {'rank': '65',
#   'title': '穿条纹睡衣的男孩',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '567685'},
#  {'rank': '66',
#   'title': '窃听风暴',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '566930'},
#  {'rank': '67',
#   'title': '情书',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '1119364'},
#  {'rank': '68',
#   'title': '两杆大烟枪',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '597213'},
#  {'rank': '69',
#   'title': '西西里的美丽传说',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '979450'},
#  {'rank': '70',
#   'title': '看不见的客人',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '1274782'},
#  {'rank': '71',
#   'title': '音乐之声',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '605379'},
#  {'rank': '72',
#   'title': '阿凡达',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '1426960'},
#  {'rank': '73',
#   'title': '拯救大兵瑞恩',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '649536'},
#  {'rank': '74',
#   'title': '哈利·波特与死亡圣器(下)',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '836075'},
#  {'rank': '75',
#   'title': '飞越疯人院',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '549138'},
#  {'rank': '76',
#   'title': '小鞋子',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '412838'},
#  {'rank': '77',
#   'title': '沉默的羔羊',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '893494'},
#  {'rank': '78',
#   'title': '布达佩斯大饭店',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '939020'},
#  {'rank': '79',
#   'title': '禁闭岛',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '981341'},
#  {'rank': '80',
#   'title': '功夫',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '1139695'},
#  {'rank': '81',
#   'title': '蝴蝶效应',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '941865'},
#  {'rank': '82',
#   'title': '致命魔术',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '860935'},
#  {'rank': '83',
#   'title': '哈利·波特与阿兹卡班的囚徒',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '734960'},
#  {'rank': '84',
#   'title': '心灵捕手',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '716246'},
#  {'rank': '85',
#   'title': '海豚湾',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '358115'},
#  {'rank': '86',
#   'title': '超脱',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '604018'},
#  {'rank': '87',
#   'title': '低俗小说',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '836999'},
#  {'rank': '88',
#   'title': '春光乍泄',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '634821'},
#  {'rank': '89',
#   'title': '摩登时代',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '302713'},
#  {'rank': '90',
#   'title': '美国往事',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '412485'},
#  {'rank': '91',
#   'title': '喜剧之王',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '974575'},
#  {'rank': '92',
#   'title': '致命ID',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '828506'},
#  {'rank': '93',
#   'title': '杀人回忆',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '717781'},
#  {'rank': '94',
#   'title': '七宗罪',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '945803'},
#  {'rank': '95',
#   'title': '红辣椒',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '466793'},
#  {'rank': '96',
#   'title': '加勒比海盗',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '862491'},
#  {'rank': '97',
#   'title': '哈利·波特与密室',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '762197'},
#  {'rank': '98',
#   'title': '一一',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '396253'},
#  {'rank': '99',
#   'title': '狩猎',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '393811'},
#  {'rank': '100',
#   'title': '唐伯虎点秋香',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '1084904'},
#  {'rank': '101',
#   'title': '7号房的礼物',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '559543'},
#  {'rank': '102',
#   'title': '被嫌弃的松子的一生',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '705970'},
#  {'rank': '103',
#   'title': '请以你的名字呼唤我',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '725720'},
#  {'rank': '104',
#   'title': '断背山',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '709140'},
#  {'rank': '105',
#   'title': '剪刀手爱德华',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '1037464'},
#  {'rank': '106',
#   'title': '爱在黎明破晓前',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '686617'},
#  {'rank': '107',
#   'title': '入殓师',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '669097'},
#  {'rank': '108',
#   'title': '蝙蝠侠：黑暗骑士崛起',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '723142'},
#  {'rank': '109',
#   'title': '勇敢的心',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '560025'},
#  {'rank': '110',
#   'title': '第六感',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '558023'},
#  {'rank': '111',
#   'title': '重庆森林',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '814157'},
#  {'rank': '112',
#   'title': '超能陆战队',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '1017887'},
#  {'rank': '113',
#   'title': '幽灵公主',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '526314'},
#  {'rank': '114',
#   'title': '爱在日落黄昏时',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '563640'},
#  {'rank': '115',
#   'title': '甜蜜蜜',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '556184'},
#  {'rank': '116',
#   'title': '菊次郎的夏天',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '598826'},
#  {'rank': '117',
#   'title': '借东西的小人阿莉埃蒂',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '556245'},
#  {'rank': '118',
#   'title': '天使爱美丽',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '956798'},
#  {'rank': '119',
#   'title': '消失的爱人',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '955453'},
#  {'rank': '120',
#   'title': '阳光灿烂的日子',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '616330'},
#  {'rank': '121',
#   'title': '小森林 夏秋篇',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '427538'},
#  {'rank': '122',
#   'title': '完美的世界',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '316487'},
#  {'rank': '123',
#   'title': '无人知晓',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '320749'},
#  {'rank': '124',
#   'title': '倩女幽魂',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '740695'},
#  {'rank': '125',
#   'title': '寄生虫',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '1375068'},
#  {'rank': '126',
#   'title': '时空恋旅人',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '675195'},
#  {'rank': '127',
#   'title': '侧耳倾听',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '464923'},
#  {'rank': '128',
#   'title': '小森林 冬春篇',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '380790'},
#  {'rank': '129',
#   'title': '幸福终点站',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '572928'},
#  {'rank': '130',
#   'title': '驯龙高手',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '758621'},
#  {'rank': '131',
#   'title': '一个叫欧维的男人决定去死',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '485144'},
#  {'rank': '132',
#   'title': '未麻的部屋',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '335042'},
#  {'rank': '133',
#   'title': '哈利·波特与火焰杯',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '664865'},
#  {'rank': '134',
#   'title': '教父3',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '376128'},
#  {'rank': '135',
#   'title': '怪兽电力公司',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '674816'},
#  {'rank': '136',
#   'title': '萤火之森',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '542032'},
#  {'rank': '137',
#   'title': '傲慢与偏见',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '804195'},
#  {'rank': '138',
#   'title': '玩具总动员3',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '519329'},
#  {'rank': '139',
#   'title': '新世界',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '437844'},
#  {'rank': '140',
#   'title': '釜山行',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '1204321'},
#  {'rank': '141',
#   'title': '神偷奶爸',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '951390'},
#  {'rank': '142',
#   'title': '被解救的姜戈',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '611078'},
#  {'rank': '143',
#   'title': '玛丽和马克思',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '422711'},
#  {'rank': '144',
#   'title': '告白',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '673493'},
#  {'rank': '145',
#   'title': '哪吒闹海',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '261154'},
#  {'rank': '146',
#   'title': '大鱼',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '569956'},
#  {'rank': '147',
#   'title': '茶馆',
#   'rating_star': '5',
#   'rating_num': '9.6',
#   'comments': '147752'},
#  {'rank': '148',
#   'title': '射雕英雄传之东成西就',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '639502'},
#  {'rank': '149',
#   'title': '九品芝麻官',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '683476'},
#  {'rank': '150',
#   'title': '头号玩家',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '1373175'},
#  {'rank': '151',
#   'title': '喜宴',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '363862'},
#  {'rank': '152',
#   'title': '模仿游戏',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '648760'},
#  {'rank': '153',
#   'title': '色，戒',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '811640'},
#  {'rank': '154',
#   'title': '阳光姐妹淘',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '591962'},
#  {'rank': '155',
#   'title': '我是山姆',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '339103'},
#  {'rank': '156',
#   'title': '花样年华',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '610060'},
#  {'rank': '157',
#   'title': '血战钢锯岭',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '785066'},
#  {'rank': '158',
#   'title': '头脑特工队',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '617263'},
#  {'rank': '159',
#   'title': '恐怖直播',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '654042'},
#  {'rank': '160',
#   'title': '七武士',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '198985'},
#  {'rank': '161',
#   'title': '惊魂记',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '296194'},
#  {'rank': '162',
#   'title': '黑客帝国3：矩阵革命',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '448525'},
#  {'rank': '163',
#   'title': '你的名字。',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '1414728'},
#  {'rank': '164',
#   'title': '电锯惊魂',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '535094'},
#  {'rank': '165',
#   'title': '三块广告牌',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '823033'},
#  {'rank': '166',
#   'title': '达拉斯买家俱乐部',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '454075'},
#  {'rank': '167',
#   'title': '疯狂原始人',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '841960'},
#  {'rank': '168',
#   'title': '心迷宫',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '523517'},
#  {'rank': '169',
#   'title': '谍影重重3',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '419727'},
#  {'rank': '170',
#   'title': '英雄本色',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '543304'},
#  {'rank': '171',
#   'title': '上帝之城',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '302248'},
#  {'rank': '172',
#   'title': '风之谷',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '355729'},
#  {'rank': '173',
#   'title': '卢旺达饭店',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '331012'},
#  {'rank': '174',
#   'title': '纵横四海',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '427235'},
#  {'rank': '175',
#   'title': '海街日记',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '450787'},
#  {'rank': '176',
#   'title': '爱在午夜降临前',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '404512'},
#  {'rank': '177',
#   'title': '绿里奇迹',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '331082'},
#  {'rank': '178',
#   'title': '记忆碎片',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '603119'},
#  {'rank': '179',
#   'title': '疯狂的石头',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '825096'},
#  {'rank': '180',
#   'title': '小丑',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '1009423'},
#  {'rank': '181',
#   'title': '岁月神偷',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '575385'},
#  {'rank': '182',
#   'title': '雨中曲',
#   'rating_star': '45',
#   'rating_num': '9.1',
#   'comments': '226970'},
#  {'rank': '183',
#   'title': '忠犬八公物语',
#   'rating_star': '45',
#   'rating_num': '9.2',
#   'comments': '196818'},
#  {'rank': '184',
#   'title': '背靠背，脸对脸',
#   'rating_star': '5',
#   'rating_num': '9.5',
#   'comments': '134992'},
#  {'rank': '185',
#   'title': '荒蛮故事',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '445323'},
#  {'rank': '186',
#   'title': '2001太空漫游',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '331149'},
#  {'rank': '187',
#   'title': '小偷家族',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '814679'},
#  {'rank': '188',
#   'title': '心灵奇旅',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '985767'},
#  {'rank': '189',
#   'title': '无间道2',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '480955'},
#  {'rank': '190',
#   'title': '无敌破坏王',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '541567'},
#  {'rank': '191',
#   'title': '爆裂鼓手',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '590237'},
#  {'rank': '192',
#   'title': '冰川时代',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '616697'},
#  {'rank': '193',
#   'title': '贫民窟的百万富翁',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '746917'},
#  {'rank': '194',
#   'title': '恐怖游轮',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '866561'},
#  {'rank': '195',
#   'title': '东邪西毒',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '578335'},
#  {'rank': '196',
#   'title': '牯岭街少年杀人事件',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '301861'},
#  {'rank': '197',
#   'title': '魔女宅急便',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '461657'},
#  {'rank': '198',
#   'title': '遗愿清单',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '463197'},
#  {'rank': '199',
#   'title': '东京教父',
#   'rating_star': '45',
#   'rating_num': '9.0',
#   'comments': '231577'},
#  {'rank': '200',
#   'title': '大佛普拉斯',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '460192'},
#  {'rank': '201',
#   'title': '你看起来好像很好吃',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '334043'},
#  {'rank': '202',
#   'title': '真爱至上',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '733021'},
#  {'rank': '203',
#   'title': '黑天鹅',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '781310'},
#  {'rank': '204',
#   'title': '可可西里',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '304286'},
#  {'rank': '205',
#   'title': '城市之光',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '147293'},
#  {'rank': '206',
#   'title': '源代码',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '837242'},
#  {'rank': '207',
#   'title': '雨人',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '405052'},
#  {'rank': '208',
#   'title': '海边的曼彻斯特',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '542680'},
#  {'rank': '209',
#   'title': '恋恋笔记本',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '673227'},
#  {'rank': '210',
#   'title': '初恋这件小事',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '982344'},
#  {'rank': '211',
#   'title': '波西米亚狂想曲',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '606450'},
#  {'rank': '212',
#   'title': '人工智能',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '448243'},
#  {'rank': '213',
#   'title': '青蛇',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '528640'},
#  {'rank': '214',
#   'title': '虎口脱险',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '258094'},
#  {'rank': '215',
#   'title': '终结者2：审判日',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '342900'},
#  {'rank': '216',
#   'title': '疯狂的麦克斯4：狂暴之路',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '532356'},
#  {'rank': '217',
#   'title': '罗生门',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '315691'},
#  {'rank': '218',
#   'title': '末路狂花',
#   'rating_star': '45',
#   'rating_num': '8.9',
#   'comments': '258250'},
#  {'rank': '219',
#   'title': '新龙门客栈',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '445948'},
#  {'rank': '220',
#   'title': '萤火虫之墓',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '405789'},
#  {'rank': '221',
#   'title': '千钧一发',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '300174'},
#  {'rank': '222',
#   'title': '崖上的波妞',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '499756'},
#  {'rank': '223',
#   'title': '无耻混蛋',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '479486'},
#  {'rank': '224',
#   'title': '彗星来的那一夜',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '582177'},
#  {'rank': '225',
#   'title': '花束般的恋爱',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '627920'},
#  {'rank': '226',
#   'title': '奇迹男孩',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '552777'},
#  {'rank': '227',
#   'title': '二十二',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '292022'},
#  {'rank': '228',
#   'title': '爱乐之城',
#   'rating_star': '4',
#   'rating_num': '8.4',
#   'comments': '901628'},
#  {'rank': '229',
#   'title': '黑客帝国2：重装上阵',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '407683'},
#  {'rank': '230',
#   'title': '芙蓉镇',
#   'rating_star': '45',
#   'rating_num': '9.3',
#   'comments': '139905'},
#  {'rank': '231',
#   'title': '血钻',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '381222'},
#  {'rank': '232',
#   'title': '战争之王',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '369954'},
#  {'rank': '233',
#   'title': '哈利·波特与死亡圣器(上)',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '578531'},
#  {'rank': '234',
#   'title': '步履不停',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '280600'},
#  {'rank': '235',
#   'title': '房间',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '368664'},
#  {'rank': '236',
#   'title': '魂断蓝桥',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '279608'},
#  {'rank': '237',
#   'title': '火星救援',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '730516'},
#  {'rank': '238',
#   'title': '千年女优',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '268563'},
#  {'rank': '239',
#   'title': '谍影重重2',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '353750'},
#  {'rank': '240',
#   'title': '弱点',
#   'rating_star': '45',
#   'rating_num': '8.7',
#   'comments': '310082'},
#  {'rank': '241',
#   'title': '白日梦想家',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '481943'},
#  {'rank': '242',
#   'title': '哈利·波特与凤凰社',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '572145'},
#  {'rank': '243',
#   'title': '阿飞正传',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '512317'},
#  {'rank': '244',
#   'title': '谍影重重',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '428044'},
#  {'rank': '245',
#   'title': '朗读者',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '454478'},
#  {'rank': '246',
#   'title': '蜘蛛侠：平行宇宙',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '666580'},
#  {'rank': '247',
#   'title': '燃情岁月',
#   'rating_star': '45',
#   'rating_num': '8.8',
#   'comments': '287616'},
#  {'rank': '248',
#   'title': '再次出发之纽约遇见你',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '427563'},
#  {'rank': '249',
#   'title': '香水',
#   'rating_star': '45',
#   'rating_num': '8.5',
#   'comments': '545209'},
#  {'rank': '250',
#   'title': '发条橙',
#   'rating_star': '45',
#   'rating_num': '8.6',
#   'comments': '365554'}]

# %%
# len(all_datas)
# Out:
# 250

# %%
# 将结果存入EXCEL
df = pd.DataFrame(all_datas)

# %%
# df
# Out:
#     rank       title rating_star rating_num comments
# 0      1      肖申克的救赎           5        9.7  2912712
# 1      2        霸王别姬           5        9.6  2150318
# 2      3        阿甘正传           5        9.5  2171440
# 3      4       泰坦尼克号           5        9.5  2202843
# 4      5     这个杀手不太冷          45        9.4  2305154
# ..   ...         ...         ...        ...      ...
# 245  246    蜘蛛侠：平行宇宙          45        8.6   666580
# 246  247        燃情岁月          45        8.8   287616
# 247  248  再次出发之纽约遇见你          45        8.6   427563
# 248  249          香水          45        8.5   545209
# 249  250         发条橙          45        8.6   365554
#
# [250 rows x 5 columns]

# %%
df.to_excel("豆瓣电影TOP250.xlsx")
